# %% [markdown]
# * Importing required modules, downloading and reading the raw dataset

# %%
import pandas as pd
url = "https://www.ers.usda.gov/webdocs/DataFiles/80591/DataDownload2015.xlsx?v=0"
df = pd.read_excel(url, sheet_name='Food Access Research Atlas')
df.sample(5)
# Out:
#        CensusTract           State      County  Urban  POP2010  OHU2010  \
# 7731    6059075806      California      Orange      1     6121     2065
# 54613  41033360702          Oregon   Josephine      1     5741     2599
# 58981  45031011400  South Carolina  Darlington      0     4249     1665
# 53756  40109102600        Oklahoma    Oklahoma      1      437      133
# 17837  12109020200         Florida   St. Johns      1     2455     1232
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10    ...      \
# 7731                   0        52  0.008495                  0    ...
# 54613                  0        27  0.004703                  0    ...
# 58981                  0       179  0.042128                  0    ...
# 53756                  0       134  0.306636                  0    ...
# 17837                  0        79  0.032179                  1    ...
#
#        TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  \
# ...

# %% [markdown]
# * Subsetting the raw dataset to filter out all the states but New York state

# %%
NYdf = df.loc[df.State == "New York"]
NYdf.sample(5)
# Out:
#        CensusTract     State        County  Urban  POP2010  OHU2010  \
# 43328  36005025200  New York         Bronx      1     2530      970
# 47069  36089490400  New York  St. Lawrence      0     3145     1345
# 47658  36111954500  New York        Ulster      0     4732     1237
# 47290  36103122405  New York       Suffolk      1     3566      955
# 44734  36047076400  New York         Kings      1     3487     1257
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10    ...      \
# 43328                  0         0  0.000000                  0    ...
# 47069                  0         0  0.000000                  0    ...
# 47658                  0      1730  0.365596                  0    ...
# 47290                  0        49  0.013741                  0    ...
# 44734                  0         0  0.000000                  0    ...
#
#        TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  \
# ...

# %% [markdown]
# * Selecting necessary columns (i.e. CensusTract and LAhalfand10)
# * Filtering out all the boroughs but the five boroughs in New York City

# %%
SelectedColumns = ["CensusTract", "LAhalfand10"]
FiveBoroughs = ["Bronx", "Kings", "New York", "Queens", "Richmond"]
FoodAccess = NYdf[NYdf["County"].isin(FiveBoroughs)].loc[:,SelectedColumns].reset_index(drop=True)
FoodAccess.sample(5)
# Out:
#       CensusTract  LAhalfand10
# 2021  36081137700            1
# 935   36047079400            0
# 1529  36081018401            0
# 1435  36081006502            0
# 531   36047024200            0

# %% [markdown]
# * Saving results to a new file

# %%
FoodAccess.to_csv("FoodAccess.csv")
